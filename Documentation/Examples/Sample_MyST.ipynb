# %% [markdown]
# # ***MyST*** Notebook
#
# MyST markdown rendering is not activated by default on noto. You need to activate it you need to check JupyterLab's extension manager (on the left hand side). Enable the `jupyterlab-myst` extension reload your browser's window.
#
# **Do not forget to deactivate your MyST extension when you are done testing!**

# %% [markdown]
# ## Simple example

# %%
import numpy as np
array = np.arange(4)

# %% [markdown]
# Let's consider the following array: {eval}`array`.
#
# We can compute the total: {eval}`array.sum()` and the maximum value is {eval}`array.max()`.

# %% [markdown]
# ## Inline graphs and foot note

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Predict the stock market, with surprising accuracy:
data = np.cumsum(np.random.rand(1000)-0.5)
data = data - np.mean(data)

stocks = plt.figure(figsize=(10,2))
ax1 = stocks.add_subplot(111)
ax1.plot(data, 'b-')
ax1.axhline(c='grey', alpha=0.5)
plt.axis('off')
plt.tight_layout()
plt.close()

annotated = plt.figure(figsize=(10,2))
ax1 = annotated.add_subplot(111)
plt.axvspan(450, 560, color='red', alpha=0.5)
plt.axvspan(600, 740, color='green', alpha=0.5)
ax1.plot(data, 'b-')
ax1.axhline(c='grey', alpha=0.5)
plt.axis('off')
plt.tight_layout()
plt.close()

# %% [markdown]
# If we look at the following stock price for [apples](https://en.wikipedia.org/wiki/Apple) ({eval}`stocks`), in the red region ({eval}`annotated`).[^note]
#
# [^note]: Both graphs are fake, of course.

# %% [markdown]
# ```{important}
# ```{note}
# Here's my `important`, highly nested note! 🪆
# ```
# ```

# %% [markdown]
# That's exactly right[^42].
#
# [^42]: Sometimes, you need to explain a point
#
#     with some extra text!
#
#     - and some *serious* points 💥
#     - and even images!
#
#     ![Beach!](https://upload.wikimedia.org/wikipedia/commons/thumb/7/73/Beach_at_Fort_Lauderdale.jpg/220px-Beach_at_Fort_Lauderdale.jpg)
#
#     Plus any preceding unindented lines,
# that are not separated by a blank line
#
# This is not part of the footnote!

# %% [markdown]
# **End of notebook**
